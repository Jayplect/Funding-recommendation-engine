# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayplect/deep-learning-AlphabetSoup/blob/main/AlphabetSoupCharity_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  In order to optimize the model's performance, I altered the model hyperparameters. These changes included:
# - Including the Name features
# - Binning the Affiliation and Name features
# - Increasing the cut-off values for the classification and application feature bins
# - Including a third hidden layer
# - Increasing the Nodes for each hidden layer
# - Increasing the epoch
#
# ---

# %% [markdown]
# ### Preprocessing

# %%
# Import our dependencies
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Check for missing data across features
application_df.isna().sum()
# Out:
# EIN                       0
# NAME                      0
# APPLICATION_TYPE          0
# AFFILIATION               0
# CLASSIFICATION            0
# USE_CASE                  0
# ORGANIZATION              0
# STATUS                    0
# INCOME_AMT                0
# SPECIAL_CONSIDERATIONS    0
# ASK_AMT                   0
# IS_SUCCESSFUL             0
# dtype: int64

# %%
# Drop the non-beneficial ID column, 'EIN'.
application_df = application_df.drop(['EIN'], axis= 1)

# Display data head
application_df.head(5)
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_unique = application_df.APPLICATION_TYPE.value_counts()
application_type_unique
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
cutoff_value = 1000
application_types_to_replace = list(application_type_unique[application_type_unique < cutoff_value].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_unique = application_df.CLASSIFICATION.value_counts()
classification_unique
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
cutoff_value = 2000
classifications_to_replace = list(classification_unique[classification_unique < cutoff_value].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at AFFILIATION value counts for binning
affiliation_unique = application_df.AFFILIATION.value_counts()
affiliation_unique
# Out:
# Independent         18480
# CompanySponsored    15705
# Family/Parent          64
# National               33
# Regional               13
# Other                   4
# Name: AFFILIATION, dtype: int64

# %%
# Choose a cutoff value and create a list of affiliations to be replaced
cutoff_value = 100
affiliation_to_replace = list(affiliation_unique[affiliation_unique < cutoff_value].index)

# Replace in dataframe
for aff in affiliation_to_replace:
    application_df['AFFILIATION'] = application_df['AFFILIATION'].replace(aff,"Other")
    
# Check to make sure binning was successful
application_df['AFFILIATION'].value_counts()
# Out:
# Independent         18480
# CompanySponsored    15705
# Other                 114
# Name: AFFILIATION, dtype: int64

# %%
# Look at NAME value counts for binning
name_unique = application_df.NAME.value_counts()
name_unique
# Out:
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: NAME, Length: 19568, dtype: int64

# %%
# Look at NAME value counts >20
name_unique[name_unique> 20]
# Out:
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
#                                                    ...
# ARIZONA FEDERATION OF GARDEN CLUBS                   21
# ALPHA PHI SIGMA INC                                  21
# AMERICAN CHRISTIAN FICTION WRITERS INC               21
# FULL GOSPEL BUSINESS MENS FELLOWSHIP IN AMERICA      21
# OREGON 4-H FOUNDATION                                21
# Name: NAME, Length: 118, dtype: int64

# %%
# Choose a cutoff value and create a list of names to be replaced
cutoff_value = 20
name_to_replace = list(name_unique[name_unique < cutoff_value].index)

# Replace in dataframe
for name in name_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name,"Other")
    
# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                             22409
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
#                                                   ...
# AMERICAN IRIS SOCIETY                                21
# ARIZONA FEDERATION OF GARDEN CLUBS                   21
# GENERAL FEDERATION OF WOMENS CLUBS ARIZONA INC       20
# DISABLED AMERICAN VETERANS AUXILIARY INC             20
# TEXAS MASTER GARDENER ASSOCIATION INC                20
# Name: NAME, Length: 122, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_dummies = pd.get_dummies(application_df)
application_df_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  NAME_AIR FORCE ASSOCIATION  \
# 0           1      5000              1                           0
# 1           1    108590              1                           0
# 2           1      5000              0                           0
# 3           1      6692              1                           0
# 4           1    142590              1                           0
# ...       ...       ...            ...                         ...
# 34294       1      5000              0                           0
# 34295       1      5000              0                           0
# 34296       1      5000              0                           0
# 34297       1      5000              1                           0
# 34298       1  36500179              0                           0
#
#        NAME_ALABAMA FEDERATION OF WOMENS CLUBS  \
# 0                                            0
# 1                                            0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_dummies['IS_SUCCESSFUL'].values
X = application_df_dummies.drop(['IS_SUCCESSFUL'],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-15-05a9737e1744>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = application_df_dummies.drop(['IS_SUCCESSFUL'],1).values

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  100
hidden_nodes_layer2 = 40
hidden_nodes_layer3 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Add a Third hidden Layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               15800
#
#  dense_1 (Dense)             (None, 40)                4040
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 1)                 21
#
# ...
# Total params: 20,681
# Trainable params: 20,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# # Create a callback that saves the model's weights every five epochs.

# %%
# Include the epoch in the file name
checkpoint_path = "./training_1/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Calculate the batch size to save per epoch
batch_size = 32
n_batches = len(X_train_scaled)/batch_size
save_period = 5

# Create a callback that saves the model's weights every 10 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    steps_per_epoch= 5,
    verbose=1, 
    save_weights_only=True,
    save_freq= int(save_period*n_batches))

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,
                   epochs=80,
                   callbacks = [cp_callback]) #pass callback to the training
# Out:
# Epoch 1/80
# 804/804 [==============================] - 3s 2ms/step - loss: 0.4827 - accuracy: 0.7633
# Epoch 2/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4617 - accuracy: 0.7737
# Epoch 3/80
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4584 - accuracy: 0.7757
# Epoch 4/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4563 - accuracy: 0.7774
# Epoch 5/80
# 795/804 [============================>.] - ETA: 0s - loss: 0.4541 - accuracy: 0.7792
# Epoch 5: saving model to ./training_1/cp-0005.ckpt
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4547 - accuracy: 0.7788
# Epoch 6/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4537 - accuracy: 0.7780
# Epoch 7/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4524 - accuracy: 0.7806
# Epoch 8/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4520 - accuracy: 0.7797
# Epoch 9/80
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4723 - accuracy: 0.7722 - 567ms/epoch - 2ms/step
# Loss: 0.4722955822944641, Accuracy: 0.7722448706626892

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization.h5')

# %%
# Save the weights
nn.save_weights('./checkpoints/my_checkpoint_AlphabetSoupCharity_Optimization')
